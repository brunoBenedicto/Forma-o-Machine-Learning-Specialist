# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoBenedicto/Forma-o-Machine-Learning-Specialist/blob/main/Redu%C3%A7%C3%A3o_de_Dimensionalidade_em_Imagens_para_Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np

# %%
def converter_para_escala_de_cinza(img_color):
    largura, altura = img_color.size
    img_cinza = Image.new('L', (largura, altura))

    for x in range(largura):
        for y in range(altura):
            r, g, b = img_color.getpixel((x, y))
            tom_cinza = int(0.2989 * r + 0.587 * g + 0.114 * b)
            img_cinza.putpixel((x, y), tom_cinza)
    return img_cinza

# %%
def converter_para_preto_e_branco(imagem):
    largura, altura = imagem.size
    img_preto_e_branco = imagem.copy()  # Cria uma cópia da imagem original

    for x in range(largura):
        for y in range(altura):
            r, g, b = imagem.getpixel((x, y))
            tom_cinza = int(0.2989 * r + 0.587 * g + 0.114 * b)

            if tom_cinza < 128:
                img_preto_e_branco.putpixel((x, y), (0, 0, 0))  # Define o pixel como preto
            else:
                img_preto_e_branco.putpixel((x, y), (255, 255, 255))  # Define o pixel como branco

    return img_preto_e_branco

# %%
arquivo = "/content/cores-768x511.jpg" 
img_color = Image.open(arquivo)
img_cinza = converter_para_escala_de_cinza(img_color)
img_preto_e_branco = converter_para_preto_e_branco(img_color)
img_color.show()
img_cinza.show()
img_preto_e_branco.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x511 at 0x7F3940FB6050>
# <PIL.Image.Image image mode=L size=768x511 at 0x7F3940FB4D90>
# <PIL.Image.Image image mode=RGB size=768x511 at 0x7F3940FB6F80>
